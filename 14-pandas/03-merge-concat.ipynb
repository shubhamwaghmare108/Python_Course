# %% [markdown]
# # Curated Pandas merge and concat lesson
# Source: `B07_Python/Merge_Concat.ipynb`.
# Execution outputs were removed for reproducible classroom practice.

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("Test_Merge.xlsx",sheet_name= "Df1")

# %%
df2 = pd.read_excel("Test_Merge.xlsx",sheet_name= "Df2")

# %%
df1

# %%
df2

# %%
df2.dtypes

# %%
df2['O_Date'] = pd.to_datetime(df2['O_Date'])

# %%
df2.iat[0,1]="2024-02-12"

# %%
df2

# %%
df1

# %%
df2

# %%
pd.merge(left=df1,right=df2,how='cross')

# %%
pd.merge(df1,df2,how='inner',on='C_Id')

# %%
pd.merge(df1,df2,how='left',on='C_Id')

# %%
pd.merge(df1,df2,how='right',on='C_Id')

# %%
pd.merge(df1,df2,how='outer',on='C_Id')

# %%
df1['Mob'] = df1['Mob'].astype(str)

# %%
state_dict={"Maharastra":['nagpur','pune'],"Gujrat":['surat'],"Kerala":['kochi']}

# %%
df1.dtypes

# %%
np.where?

# %%
df1['Mobile_status']=np.where(df1['Mob'].str.len()==10,'Valied','Invalied')

# %%
df1

# %%
assesser -- str,dt,cat

# %%
df2

# %%
pd.to_datetime?

# %%
df = pd.DataFrame({'year': [2015, 2016],
                    'month': [2, 3],
                  'day': [4, 5]})

# %%
df

# %%
pd.to_datetime(df)
