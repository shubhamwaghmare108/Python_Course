# %% [markdown]
# # Pandas DataFrames
#
# Learn the core two-dimensional pandas structure before selection and filtering.
#
# ## Topics
# - create DataFrames from dictionaries and records
# - inspect `shape`, `columns`, `dtypes`, `info()`
# - preview with `head()`, `tail()`, `sample()`
# - add and rename columns
# - save/load CSV
#
# ## Practice
# Create a small employee DataFrame, inspect it, add a calculated column, and save it as CSV.

# %%
import pandas as pd

df = pd.DataFrame({'name':['Asha','Ravi','Neha'],'department':['Data','IT','Data'],'salary':[55000,62000,58000]})
df['salary_k'] = df['salary'] / 1000
print(df)
print(df.shape)
print(df.dtypes)
