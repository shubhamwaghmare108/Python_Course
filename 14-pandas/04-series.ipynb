# %% [markdown]
# # Pandas Series
#
# Learn the one-dimensional labeled data structure used throughout pandas.

# %% [markdown]
# ## 1. Creating a Series
#
# ```python
# import pandas as pd
#
# scores = pd.Series([72, 85, 91], index=["Asha", "Ravi", "Neha"], name="score")
# print(scores)
# ```

# %% [markdown]
# ## 2. Indexing and selection
#
# Practice label-based selection with `.loc` and positional selection with `.iloc`.

# %% [markdown]
# ## 3. Series attributes
#
# Inspect `index`, `values`, `dtype`, `size`, and `name`.

# %% [markdown]
# ## 4. Vectorized operations
#
# Perform arithmetic and comparisons without explicit Python loops.

# %% [markdown]
# ## 5. Missing values
#
# Use `isna()`, `notna()`, `fillna()`, and `dropna()` appropriately.

# %% [markdown]
# ## 6. Aggregations
#
# Practice `sum()`, `mean()`, `min()`, `max()`, and `value_counts()`.

# %% [markdown]
# ## Practice
#
# Create a student-score Series, identify the highest score, calculate the class average, filter passing students, and handle one missing score.
