# %% [markdown]
# # Curated lesson: 03-lambda
# Source: `B07_Python/Day14 -lambda.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %% [markdown]
# ## Lambda function

# %%
(lambda x,y:(x+y))(5,41)

# %%
(lambda x,y:[(x+y),(x-y),(x*y)])(5,41)

# %%
(lambda x,y:x+y)(5,41)

# %%
y = lambda x,y:x+y

# %%
y(20,30)

# %% [markdown]
# A lambda function is a small, anonymous, single-expression function. They are useful for short-term, throwaway functions.

# %%
# Regular function
def square(x):
    #print(x * x)
    return x*x

# Equivalent lambda function
square_lambda = lambda x: x * x
print(square(5))
print(square_lambda(5))

# %%
s = square(5)

# %%
s

# %%
d = (lambda x,y:x+y)(10,23)

# %%
d

# %%
square(5)

# %%
square = lambda x: x ** 2
print(square(4))

# %%
double = lambda x: x * 2
print(double(5))

# %%
lis=[1,2,3]
list(map(double,lis))

# %%
map?

# %%
nums = [1, 2, 3, 4, 5]

# Double each element
doubled = list(map(lambda x: x * 2, nums))
print(doubled)  # Output: [2, 4, 6, 8, 10]

# %%
# Filter even numbers
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens) 
list(filter(lambda x:x>2,nums))

# %%
filter?

# %%
list(filter(None,[[1],12.5,0,""]))

# %%
lis_org=[1,2,3,4,5]
lis_res=[]
for i in lis_org:
    lis_res.append(i*2)

# %%
lis_res

# %%
def double_std(lis):
    lis_res=[]
    for i in lis:
        lis_res.append(i*2)
    return lis_res

# %%
double_std([1,2,3,4,5])

# %%
def double(x):
    return x*2

# %%
list(map(double,[1,2,3]))

# %%
globals()

# %%
locals()

# %%
x = 10
y = 20

def add():
    x = 20
    print(x,"local")
    print(y,"global")
    print(x+y)
print(x)
print(y)
add()

# %%
x = "global"

def s1():
    x = "Enclosing"
    print(x)
    def s2():
        x = "Local"
        print(x)
    s2()
print(x)
s1()
print(x)

# %%
globals()

# %%
globals()['x'] = 10

# %%
globals()

# %%
locals()

# %%
x = 10

def add():
    x += 10

add()

# %%
x = 10

def add():
    global x
    x += 10

add()

# %%
print(x)

# %%
x = 60

def add():
    x = 20
    x += 10
    print(x)

add()
print(x)

# %%
x = 60

def add():
    global x
    x = 40
    print(x)
    
    x += 10
    print(x)

print(x)
add()
print(x)

# %%
x = 60

def add():
    x = 40
    print(x)
    
    def add2():
        nonlocal x
        x += 10
        print(x)
    
    add2()
    print(x)

print(x)
add()
print(x)

# %%
x = 60

def add():
    #nonlocal x
    #global x
    x = 40
    print(x)
    print(locals())
    
    def add2():
        #nonlocal x
        x = 20
        print(x)
        print(locals())

        def add3():
            nonlocal x
            x += 30
            print(x)
            print(locals())
        
        add3()
        print(locals())
    
    add2()

print(x)
add()
print(x)

# %%
globals()['x']

# %%
globals()['x'] = 30

# %%
globals()['x']

# %%
locals()

# %%
globals()['xyz']

# %%
globals()['xyz'] = 25

# %%
globals()['xyz']

# %%
x = 100

def show():
    print(globals())

show()

# %%
print(globals()['y'])

# %%
globals()['y'] = 30

# %%
globals()['y']

# %%
y

# %%
def my_func():
    a = 10
    b = 20
    locals()['x'] = 50
    locals()['a'] = 100
    #print(locals())
    print(globals())

my_func()

# %%
def fac(x):
    if x == 0:
        return 1
    return x*fac(x-1)

# %%
fac(5)
