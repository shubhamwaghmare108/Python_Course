# %% [markdown]
# # Curated lesson: 02-functions-practice
# Source: `B07_Python/Day13- Function.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %%
print("Hello,Everyone")

# %% [markdown]
# # Standard Function in python

# %% [raw]
# def functionname(parameter-optional):
#     main body
#     optional return

# %%
def addition(x:int,y:int)->int:
    """Takes two input and return there addition as output.
    Example:
        addition(12,35)==>> 47,
        addition([1,2],[3,4])==>> [1,2,3,4]"""
    return x+y

# %%
print?

# %%
addition?

# %%
addition(123.25,586.12)

# %%
addition([3,4],[1,2])

# %%
addition('shubham ','waghmare')

# %%
addition(12,25)

# %%
def addition(x,y):
    print("Hello,User.\nThis is the result of your calculation:")
    print(x),print(y)
    print(x+y)
   # return
    print("Hello")

# %%
print(10,23)

# %%
a = addition(10,20)

# %%
a

# %%
print(a)

# %%
type(a)

# %%
b

# %%
c

# %%
addition("Shubham ","Waghmare")

# %%
z = addition("Shubham"," dfff")

# %%
z

# %%
def addition(x,y):
    print(x+y)

# %%
addition(10,51)

# %%
y = addition(10,51)

# %%
y

# %%
print(y)

# %%
def greet():
    print("Hello,User!")

# %%
greet()

# %%
greet("Shubham")

# %%
addition(10,20,30)

# %% [markdown]
# ## default argument

# %%
print?

# %%
def greet(name = "User"):
    print(f"Hello,{name}!")

# %%
greet("Shubham")

# %%
greet()

# %%
greet?

# %%
#positional,keyward

# %%
greet(name = "Shubham")

# %%
greet(x = "shubham")

# %%
def sub(x:int = 1,y:int = 1)->int:
    """
    takes two arguments x and y and return there subtraction
    """
    return x - y

# %%
sub(x = 5,y = 10)

# %%
sub(y = 5,x = 10)

# %%
sub?

# %%
sub(5,10)

# %%
sub(10,5)

# %%
sub(10)

# %%
sub(y=5)

# %% [markdown]
# ## order of arguments

# %%
sub(y = 10,5)

# %% [markdown]
# ## first -positional,then -keyward

# %%
sub(x=10,5)

# %%
sub(5,y = 5)

# %%
sub(5,x = 5)

# %%
sub?

# %%
sub()

# %%
def sub(x:int = 1,*,y:int = 1)->int:
    """
    takes two arguments x and y and return there subtraction
    """
    return x - y

# %%
sub(10,20)

# %%
sub(10,y=20)

# %%
sub(x=20,y=30)

# %%
print?

# %% [markdown]
# ### variable length argument

# %%
#*args,**kwargs

# %%
def minus(x,y,/,z):
    return x-y-z

# %%
minus(10,5,2)

# %%
minus(x=10,y=5,z=2)

# %%
minus(10,5,z=2)

# %%
def minus(x,y,/,z,c,*,d,f):
    return x-y-z-c-d-f

# %%
minus(10,20,3,54,64,58)

# %%
parameter :
    1.positional only before /
    2.keyword only after *
    3.standard -(p+k)

# %%
minus?

# %%
minus(10,20,3,54,d=64,f=58)

# %%
minus(10,20,3,54,f=58,d=64)

# %%
minus(10,20,z=3,c=54,f=58,d=64)

# %%
minus(10,20,3,c=54,f=58,d=64)

# %%
minus?

# %%
minus(10,20,3,z=54,f=58,d=64)

# %%
def add(*nums):
    return nums,type(nums)

# %%
add(10,20,3)

# %%
def minus(**nums):
    print(nums)
    return type(nums)

# %%
minus(12,35,56)

# %%
minus(x=12,y=35,z=56)

# %%
def minus(z,x,c,*args):
    return args,z,x,c

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)

# %%
minus(z=1,x=2,c=0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)

# %%
minus(z=1,x=2,c=0)

# %%
def minus(*args,z,x,c):
    return args,z,x,c

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,z=4,x=0,c=4)

# %%
def fd(c,v):
    return c*v
    print("ok")

# %%
fd(5,3)

# %%
fd(c=5,v=3)

# %%
fd(5,v=3)

# %%
fd(v=5,3)

# %%
fd(5,c=3)

# %%
def addition(x,y):
    return x + y

# %%
addition(5,3)

# %%
sum?

# %%
def addition(*nums):
    print(type(nums))
    print(nums)
    return sum(nums)

# %%
addition(5,3)

# %%
addition(5,3,8)

# %%
addition()

# %%
(3,5,8)

# %%
(12,3)+(3,)

# %%
def addition(name,**nums):
    print(type(nums))
    print(nums)
    print(name)

# %%
addition("Shubham")

# %%
addition(name="Shubham",age = 30,edu = "Graduate")

# %%
def info(name,*marks,**result):
    print(name)
    print(sum(marks))
    print(result)

# %%
info("shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")

# %%
info(name = "shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")

# %%
info(80,90,99,100,75,grade = "distinction",final_result = "pass",name = "shubham")

# %%
def sd(science,maths,*marks):
    print(science)
    print(maths)
    print(marks)

# %%
sd(20,30,50,"shubham",70)

# %%
sd(20,30)

# %%
def sd(science,/,maths,**subjects):
    print(science)
    print(maths)
    print(subjects)

# %%
sd(45,65,history = 75,literature = 80)

# %%
sd(science = 45,maths = 65,history = 75,literature = 80)

# %%
def sd(science,*,maths,**subjects):
    print(science)
    print(maths)
    print(subjects)

# %%
sd(45,65,history = 75,literature = 80)

# %%
sd(science = 45,maths = 65,history = 75,literature = 80)
