# %% [markdown]
# # Curated lesson: 01-function-fundamentals
# Source: `B07_Python/Day10.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %% [markdown]
# # While loop in python

# %%
while True:
    print(1)

# %%
while False:
    print(1)

# %%
while True:
    print(1)
    break

# %%
while True:
    continue
    print(1)
    break

# %%
while True:
    print(1)
    continue
    print(1)
    break

# %%
while True:
    print(1)
    if 0:
        continue
    print(1)
    break

# %%
num = 10
while num == 10:
    print(f"Ok for num = {num}")
    num += 3
print("Out")

# %%
num = 100
while num < 10:
    print("In")
    print(f"Ok for num = {num}")
    num += 1
print("Out")

# %%
lis = [1,5,65,89]

# %%
i = 0
while lis[i] !=10:
    print(f"Not 10 but {lis[i]}")
    i -=1
else:
    print("10 found")
print("Out")

# %%
lis = [1,5,65,10,89]
i = 0
while lis[i] !=10:
    print(f"Not 10 but {lis[i]}")
    i +=1
else:
    print(f"10 found at index num= {i}")
print("Out")

# %%
lis[3]

# %%
lis = [1,5,65,10,89]
i = 0
while lis[i] !=10:
    print("Process never going to stop")
    #break

# %%
lis = [1,5,65,10,89]
j = 1
i = 0
while lis[i] !=10:
    print("Process never going to stop",j)
    j += 1
    if j > 100:
        break
else:
    print("loop ended")
print("Out")

# %%
lis = [1,5,65,10,89]
i = 0
while lis[i] !=10:
    i+=1
else:
    print("loop ended")
print("Out")

# %%
lis = [1,5,65,10,89]
i = 0
while lis[i] !=10:
    i+=1
    break
else:
    print("loop ended")
print("Out")

# %%
lis = [1,5,65,89,10,59]
i = 0
while lis[i] !=10:
    print(lis[i])
    i+=1
    
    if i ==4:
        break
else:
    print("loop ended")
print("Out")

# %%
lis = [1,5,65,89,10,59]
i = 0
while lis[i] !=10:
    print(lis[i])
    i += 1
    if i == 4:
        continue
    print(lis[i]) 
else:
    print("loop ended")
print("Out")

# %%
lis = [1,5,6,8,"shubham",4,2,6,6.5]
i = 0
even = []
odd = []
while True:
    if len(lis) == i:
        print("Index reached its limit")
        break
    elif isinstance(lis[i],int):
        if lis[i] % 2 == 0:
            even.append(lis[i])
            i += 1
            continue
        odd.append(lis[i])
        i += 1
    elif isinstance(lis[i],float):
        
        if int(lis[i]) % 2 == 0:
            even.append(int(lis[i]))
            i += 1
            continue
        odd.append(int(lis[i]))
        i += 1
    else:
        i += 1

# %%
even

# %%
odd

# %%
lis = [1,5,6,8,6,"sdhg",2,6]
i = 0
even=[]
odd=[]
while len(lis)>i:
    if isinstance(lis[i],int):
        if lis[i] % 2 == 0:
            even.append(lis[i])
            i += 1
            continue
        odd.append(lis[i])
        i += 1
    else:
        i +=1

# %%
lis = [1,5,6,8,6,"sdhg",2,6]
i = 0
even=[]
odd=[]
while len(lis)>i:
    if isinstance(lis[i],int):
        if lis[i] % 2 == 0:
            even.append(lis[i])
            i += 1
            continue
        odd.append(lis[i])
        i += 1
    else:
        i +=1

# %%
even

# %%
odd

# %%
a=shubham

# %%
b= sdfg

# %%
def even_odd_seperator(interable):
    """Give an iterable and get even and odd as result list"""
    i = 0
    even = []
    odd = []
    while True:
        if len(lis) == i:
            print("Index reached its limit")
            break
        elif isinstance(lis[i],int):
            if lis[i] % 2 == 0:
                even.append(lis[i])
                i += 1
                continue
            odd.append(lis[i])
            i += 1
        elif isinstance(lis[i],float):
        
            if int(lis[i]) % 2 == 0:
                even.append(int(lis[i]))
                i += 1
                continue
            odd.append(int(lis[i]))
            i += 1
        else:
            i += 1
    return even,odd

# %%
even_list,odd_list = even_odd_seperator(lis)

# %%
even_list

# %%
odd_list

# %%
even_odd_seperator?
