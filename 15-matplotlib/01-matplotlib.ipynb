# %% [markdown]
# # Curated lesson: 01-matplotlib
# Source: `B07_Python/Matplotlib.ipynb`.
# Migrated and cleaned for the structured Python Course. Execution outputs were removed.

# %%
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Titanic.xlsx")

# %%
df

# %%
df.set_index("PassengerId",inplace = True)

# %%
df

# %%
survival_rate_by_sex = df.groupby('Sex')['Survived'].sum()

# %%
survival_rate_by_sex

# %%
plt.figure(figsize=(6,4))
plt.bar(survival_rate_by_sex.index,survival_rate_by_sex)
plt.title("Survival Count by Gender Analysis")
plt.xlabel("Gender")
plt.xticks(rotation = 360)
plt.ylabel("Count")
plt.yticks(color ='red')

# %%
survival_rate_by_sex.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Survival Rate on the Titanic by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.xticks(rotation=90)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# %%
x= df.groupby("Pclass")["Survived"].sum()

# %%
x

# %%
plt.figure(figsize=(5,3))
plt.barh(x.index,x)
plt.title("barh")
plt.xlabel("survived passenger count")
plt.ylabel("pclass")

# %%
df.groupby("Pclass")["Survived"].sum().plot(kind="barh")
plt.xticks(rotation=0)

# %%
df["Survived"].value_counts()

# %%
df["Survived"].value_counts().plot(kind="bar")
plt.xticks(rotation = 0)

# %%
df["Pclass"].value_counts().sort_values().plot(kind="bar")
plt.xticks(rotation=0)

# %%
plt.pie?

# %%
plt.pie(df.groupby("Pclass")["Survived"].sum().sort_values(),labels=df.groupby("Pclass")["Survived"].sum().sort_values().index,labeldistance = 0.5)

# %%
df.groupby("Pclass")["Survived"].sum().sort_values().plot(kind="pie")

# %%
plt.hist(df["Pclass"])

# %%
df["Pclass"].plot(kind="hist")

# %%
x = np.linspace(0, 10, 100)  # 100 points between 0 and 10
y = np.sin(x)

plt.plot(x, y, label="sin curve", color="blue", linestyle="--", marker="x")
plt.title("Basic Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(False)
plt.show()

# %%
y2 = np.tan(x)

plt.plot(x, y, label="sin(x)", color="blue")
plt.plot(x, y2, label="tan(x)", color="red")
plt.title("Multiple Line Plots")
plt.xlabel("X")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15,5)) #oo

axs[0,0].plot(x, y, color="blue"); axs[0,0].set_title("sin(x)")
axs[0,1].plot(x, y2, color="red"); axs[0,1].set_title("tan(x)")
axs[1,0].scatter(x, y, color="green"); axs[1,0].set_title("Scatter")
axs[1,2].hist(y, bins=20, color="purple"); axs[1,1].set_title("Histogram")

plt.tight_layout()
plt.show()

# %%
plt.hist(df["Fare"],bins=[0,30,50,100,200,300,400,600])

# %%
sizes = [30, 20, 25, 25]
labels = ["A", "B", "C", "D"]

plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Pie Chart")
plt.show()

# %%
plt.plot?

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 15, 20, 25]

plt.plot(x, y, color="c", linestyle=":", marker="s", markersize=20, linewidth=2)
plt.title("Customized Line Plot")
plt.xlabel("Day")
plt.ylabel("Price")
plt.show()

# %%
y2 = [5, 7, 10, 12, 15]

plt.plot(x, y, label="Series 1",color="red",marker="o",linewidth=2)
plt.plot(x, y2, label="Series 2",color="orange",marker="*",linestyle="--")
plt.legend()
plt.title("Multiple Line Plot")
plt.show()

# %%
categories = ["A", "B", "C", "D"]
values = [23, 45, 56, 78]

plt.bar(categories, values, color="skyblue")
plt.title("Bar Chart Example")
plt.xlabel("Catagory")
plt.ylabel("Count")
for i, v in enumerate(values):
    plt.text(i, v + 1, str(v), ha="center", fontweight="bold")
plt.show()

# %%
ax.bar_label?

# %%
categories = ["A", "B", "C", "D"]
values = [23, 45, 56, 78]

fig, ax = plt.subplots()
bars = ax.bar(categories, values, color="orange")

# Add value labels
ax.bar_label(bars, label_type="center")

plt.title("Bar Chart with Data Labels")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 15, 20, 25]
plt.scatter(x, y, color="green")
plt.title("Scatter Plot")
plt.show()

# %%
data = np.random.randn(1000)

plt.hist(data, bins=30, color="purple", alpha=0.5)
plt.title("Histogram Example")
plt.show()

# %%
x = np.linspace(0, 10, 100)

plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))
plt.title("Sine Wave")

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))
plt.title("Cosine Wave")

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))
plt.title("Tangent")

plt.subplot(2, 2, 4)
plt.hist(np.random.randn(1000), bins=30)
plt.title("Histogram")

plt.tight_layout()
plt.show()

# %%
plt.style.use('seaborn-v0_8-white')   # Seaborn styles are now namespaced as seaborn-v0_8-*
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.title("Styled Plot with ggplot")
plt.show()

# %%
plt.style.available

# %%
days = np.arange(1, 11)
prices = [100, 102, 98, 105, 110, 108, 112, 115, 117, 120]
plt.style.use('seaborn-v0_8-dark')
plt.plot(days, prices, marker="o", color="blue",linestyle=":", label="Stock Price")
plt.title("Stock Price Trend")
plt.xlabel("Days")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# | String      | Short Code | Appearance    |
# | ----------- | ---------- | ------------- |
# | `'solid'`   | `'-'`      | ─────────     |
# | `'dashed'`  | `'--'`     | – – – – – – – |
# | `'dotted'`  | `':'`      | ···········   |
# | `'dashdot'` | `'-.'`     | – · – · –     |

# %%
fig, axs = plt.subplots(3, 1, sharex=False, figsize=(6, 8))

x = np.linspace(0, 10, 100)

axs[0].plot(x, np.sin(x))
axs[0].set_title("sin(x)")

axs[1].plot(x, np.cos(x), color="red")
axs[1].set_title("cos(x)")

axs[2].plot(x, np.sin(x) + np.cos(x), color="green")
axs[2].set_title("sin(x)+cos(x)")
plt.savefig("demo.pdf",dpi=500)
plt.tight_layout()
plt.show()
