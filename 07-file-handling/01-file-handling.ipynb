# %% [markdown]
# # Curated lesson: 01-file-handling
# Source: `B07_Python/FileHandling.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %%
file = open("shubham.txt","r")

# %%
file.read()

# %%
file.read()

# %%
file.tell()

# %%
file.seek(0)

# %%
file.read(5)

# %%
file.read()

# %%
file.tell()

# %%
file.read()

# %%
file.close()

# %%
file = open("shubham.txt","w")

# %%
file.close()

# %%
file = open("shubham.txt","r")

# %%
file.read(10)

# %%
file.seek(0,0)

# %%
file.readline()

# %%
file.seek(0,0)

# %%
file.readlines()

# %%
file.close()

# %%
file = open("shubham1.txt","x")
file.close()

# %%
file.close()

# %%
file = open("shubham.txt","a")

# %%
file.write("\nThis is my first file handling program in python")

# %%
file.close()

# %%
file.read()

# %%
file = open("B12.txt","w")

# %%
file.write("Hello Student")

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()

# %%
file.close()

# %%
from pathlib import Path

file_path = Path('sample_data') / 'ddl_dml_tcl.sql'
file = file_path.open('rb')

# %%
file.read()

# %%
file.tell()

# %%
file.seek?

# %%
file.seek(0,0)

# %%
file.read()

# %%
file.tell()

# %%
file.seek(5,0)

# %%
file.read()

# %%
file.seek(10,1)

# %%
file.tell()

# %%
file.seek(-3,1)

# %%
file.seek(3,1)

# %%
file.seek(-5,2)

# %%
file.seek(-5,1)

# %%
file.seek(0,2)

# %%
file.close()

# %%
file.read()

# %%
file.tail()

# %%
file.seek(-1,2)

# %%
file.seek(2,1)

# %%
file.close()

# %%
file = open("B12.txt","wb")

# %%
file.read()

# %%
file.write(b"Hello Class")

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()

# %%
file.write("123")

# %%
file.close()

# %%
file = open("B12.txt","a")

# %%
file.read()

# %%
file.write("\nHello student")

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.readline()

# %%
file.seek(0,0)

# %%
file.readlines()

# %%
file.close()

# %%
file = open("B12.txt","x")

# %%
file = open("B14.txt","x")

# %%
file.close()

# %%
file = open("B15.txt","a")

# %%
file.write("I love Python")

# %%
file.writelines(["I love Python", "I love Java"])

# %%
file.close()

# %%
file = open("B13.txt","r+")

# %%
file.read()

# %%
file.tell()

# %%
file.seek(5,0)

# %%
file.read()

# %%
file.seek(-3,2)

# %%
file.read()

# %%
file.tell()

# %%
file.seek(0,0)

# %%
file.seek(0,2)

# %%
file.write("This is my first file handling program in python")

# %%
file.close()

# %%
file = open("B15.txt","r+")

# %%
file.close()

# %%
file = open("B17.txt","w+")

# %%
file.write("Hello Student")

# %%
file.tell()

# %%
file.seek(0,0)

# %%
file.read(10)

# %%
file.seek(0,0)

# %%
file.seek(-2,1)

# %%
file.read(5)

# %%
file.tell()

# %%
file.read(2)

# %%
file.close()

# %%
file = open("B13.txt","rb+")

# %%
file.readline()

# %%
file.readline()

# %%
file.readline()

# %%
file.readline()

# %%
file.readline?

# %%
file.tell()

# %%
file.seek(0,0)

# %%
file.readlines()

# %%
file.readlines()

# %%
file.write(b"\nI Love Machine Learning")

# %%
file.tell()

# %%
file.seek(0,0)

# %%
file.readlines()

# %%
file.write(b"\nI Love Machine Learning")

# %%
file.seek(0)

# %%
inputlines = file.readlines()

# %%
file.writelines(inputlines)

# %%
file.tell()

# %%
file.seek(0)

# %%
file.readlines()

# %%
file.close()
