# %% [markdown]
# # Curated lesson: 03_dictionaries
# Source: `B07_Python/Day9.ipynb`.
# This notebook was migrated into the structured Python Course and execution outputs were removed so students can run the examples themselves.

# %% [markdown]
# # Looping in Python

# %% [markdown]
# ## For Loop

# %%
x = range(100000,100013,3)

# %%
list(x)

# %%
tuple(x)

# %%
set(x)

# %%
str2 = "shubham"
#str2[5]
#str2[-2]
str2[0:3] #start:stop:step

# %%
"shubham"[5]

# %%
list(range(1,101,1))

# %%
range?

# %%
range(2)

# %%
for num in range(10): # 0-9 all included
    print(num)

# %%
for num in range(1,11):# 1-10 all included
    print(num * 10)

# %% [markdown]
# ### for loop operate till data is exuasted

# %% [markdown]
# ### for loop already knows how many time to run a task

# %%
for char in "sdfghj":
    print(char)

# %%
for elem in [1,5,"sdfsg",9]:
    print(elem)

# %%
for elem in (5,10,"sh",89):
    print(elem)

# %%
for elem in {1,5,6,5,4}:
    print(elem)

# %%
a = '123456'

# %%
b = iter(a)

# %%
next(b)

# %%
{"name":"shubham","age":29}.items()

# %%
b,c,d=(10,20,30)

# %%
[*d]

# %%
d=10,20

# %%
type(d)

# %%
for key,value in {"name":"shubham","age":29}.items():
    print(key,"---->>",value)

# %%
a =123456
b = iter(a)
next(b)

# %%
for num in 123456:
    print(num)

# %%
for num in "123456":
    print(num)

# %%
for i in range(10):
    pass

# %%
for i in range(10):
    pass
print("hs")
print(123)

# %%
if 54 == 45:
    pass
else:
    print("ok")

# %%
for i in range(10):
    print(1)
print("hs")
print(123)

# %%
for i in range(10):
    pass

# %%
# pass is placeholder for syntax purpose.

# %% [markdown]
# ## break keyword in for loop

# %%
for i in range(10):
    if i==5:
        print("5 found")
        break
    else:
        print(f"not 5 but {i}")

# %%
for i in range(10):
    print(i)
    break
print("Out")

# %%
for i in range(10):
    print(i)
    #break
print("Out")

# %%
for i in range(1,10):
    print(i)
    if i % 2 == 0:
        print(i)
        print("Even")
        break

# %%
for i in  range(10):
    if i == 5:
        continue
    print(i)
    print(123)

# %%
for i in range(10):
    if i % 2!= 0:
        continue
    print(i)
else:
    print("15 not found")

# %%
for i in range(10):
    if i == 5:
        print("5 found")
        break
else:
    print("5 not found")

# %%
for i in range(4):
    if i == 5:
        print("5 found")
        break
else:
    print("5 not found")

# %%
# if break then else will not execute vice versa

# %%
for i in range(10):
    if i == 5:
        continue
else:
    print("5 not found")

# %%
lis=[1,5,6,4,5]

# %%
for i in lis:
    print(f"In with i={i}")
    if i == 5:
        print("5 found")
        break
else:
    print("5 not found")
print("Out")

# %%
lis1 = [1,3,4]

# %%
for i in lis1:
    if i == 5:
        print(f"{i} is already present,No need to add.")
        break
else:
    lis1.append(5)

# %%
lis1

# %%
for i in lis1:
    if i == 5:
        print(f"{i} is already present,No need to add.")
        break
else:
    lis1.append(5)

# %%
lis1

# %%
name = input("Enter your name user: ")
print(f"Hello,{name}")

# %%
print(f"Hello,shubham")

# %%
"Hello {0},{1}".format("shubham","nikita")

# %%
"Hello {1},{0}".format("shubham","nikita")

# %%
"Hello {name1},{name2}".format(name1="shubham",name2 = "nikita")

# %%
"Hello %s,%d"%("shubham",123)

# %%
name = "Shubham"
age = 25

result = "My name is %s and I am %d years old." % (name, age)
print(result)

# %%
f"My name is {name} and I am {age} years old."

# %%
"My name is {name} and I am {age} years old.".format(name=name,age=age)

# %%
i = 1
while i <= 10:
    print(i)
    break

# %%
tup = (1,2,3,4,5,6)
odd = []
even = []
for i in tup:
    if i % 2 == 0:
        even.append(i)
    else:
        odd.append(i)

# %%
odd

# %%
even

# %%
x = 5

# %%
x = 10

# %%
x

# %%
name = "shubham"
str3 = "aeiou"
for i in name:
    if i in str3:
        print(i)

# %%
"x" in str1

# %%
str1

# %%
i = 0
while len(name)> i:
    if name[i] in str3:
        print(name[i])
    i += 1

# %%
num = 5

for i in range(num):
    print()
    for j in range(i+1):
        print("*",end =" ")

# %%
num = 5
for i in range(num):
    print(" "*(5-i),("* "*i))

# %%
num = 5
for i in range(num):
    print("*"*(5-i))

# %%
num = 5
for i in range(num):
    print(" "*i,"*"*(5-i))

# %%
num = 5
for i in range(num):
    print(" "*i,"* "*(5-i))
