# %% [markdown]
# # Curated lesson: 02_sets
# Source: `B07_Python/Day8.ipynb`.
# This notebook was migrated into the structured Python Course and execution outputs were removed so students can run the examples themselves.

# %% [markdown]
# # Tuple

# %% [markdown]
# tuple - - > ()

# %%
tup1 = tuple()

# %%
type(tup1)

# %%
print(tup1)

# %%
tup2 =()

# %%
tup2

# %%
tup3 = (1)

# %%
type(tup3)

# %%
tup3 = (1,)

# %%
type(tup3)

# %% [markdown]
# ## Tuple is immutable collection-- size can not grow or shrink

# %%
tup2 = (1,2,5,6,4)

# %%
type(tup2)

# %%
tup2[0]

# %%
tup2[-1]

# %%
tup2[-4:-1]

# %% [markdown]
# ## indexing and slicing supported

# %%
tup3 = (1,2,5,"adfh",[25,56],(56,"sdfs"))

# %%
len(tup3)

# %%
del tup3[0]

# %%
tup3

# %%
tup3[0] = 25

# %%
tup3[4][1]# chaining

# %%
tup3[4][1] = 57

# %%
tup3

# %%
tup3[-1][0] = 45

# %% [markdown]
# ## Tuple Methods

# %%
tup3

# %%
tup3.count?

# %%
tup3.count(1)

# %%
tup3.count("f")

# %%
tup3.count(5)

# %%
tup3.count(57)

# %%
tup3

# %%
tup3[4].count(57)

# %%
tup3.index(5,3)

# %%
tup3.index("g")

# %% [markdown]
# ### List Vs Tuple

# %%
lis = [1,2,3,4]

# %%
tup = (1,2,3,4)

# %%
import sys

# %%
sys.getsizeof(lis)

# %%
sys.getsizeof(tup)

# %%
sys.getsizeof?

# %%
16/72

# %%
# memory wise tuple is more efficient

# %%
# tuple is faster than list because  of operation overhead

# %%
# flexibility is inbuilt in list

# %% [markdown]
# ## Tuple can be hashable or vice versa

# %%
(1,2,3) + (2,5,6)

# %%
(1,2,3) * 3

# %%
[1,2,3] + [4,5,6]

# %%
[1,2,3] * 3
