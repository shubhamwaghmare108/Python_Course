# %% [markdown]
# # Curated lesson: 04-set-practice
# Source: `B07_Python/Day11-set.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %% [markdown]
# # Set in Python

# %% [markdown]
# ## How to make an empty set

# %%
type({})

# %%
type(set())

# %%
type(str())

# %%
type(list())

# %%
list()

# %%
dict()

# %%
a = set()

# %%
a

# %%
a.

# %%
invitation_list = set()

# %%
invitation_list.add("Bhagwan Ji")

# %%
invitation_list

# %%
invitation_list.add("Rohit")

# %%
invitation_list.add("Diksha")

# %%
len(invitation_list)

# %%
invitation_list

# %%
invitation_list.add("Rohit")

# %%
invitation_list

# %%
a

# %%
a.add(56)

# %%
a.add([1,2])

# %% [markdown]
# ## How to add elements in set as it is mutable it can grow or shrink

# %%
se1 = set()

# %%
se1

# %%
se1.add?

# %%
se1.add(10)

# %%
se1

# %%
se1.add(10) # duplicates are not allowed in set

# %%
se1

# %%
se1.add(20)

# %%
se1

# %%
se1.add(5)

# %%
se1

# %%
se1.add(15)

# %%
se1

# %% [markdown]
# ## indexing

# %%
len(se1)

# %%
se1[0]

# %%
se1.add("sdfdj")

# %%
se1

# %%
se1.add(145)

# %%
se1

# %%
se1.add(0)

# %%
se1

# %%
se1.add((1,5))

# %%
se1

# %% [markdown]
# ## set are mutable but unordered

# %%
se1[1:3]

# %%
se1

# %%
for i in se1:
    print(i)

# %% [markdown]
# ## what item/object can be placed inside a set

# %%
se1

# %%
se1.add(([1],()))

# %% [markdown]
# ## only hashable data

# %% [markdown]
# ## hashable means that doen't mutate/change in its entire lifetime

# %%
se1.add({1,5,6})

# %%
se1.clear()

# %%
se1

# %%
se1.add(1,3,5)

# %%
se1.add(1)

# %%
se1.add(10)

# %%
se1.add("adfa")

# %%
se1.add(12.36)

# %%
se1

# %% [markdown]
# ### set are fast for serching

# %%
se2 = se1.copy()

# %%
se2

# %%
se1.pop?

# %%
se1.pop()

# %%
se1.pop()

# %%
se1.pop()

# %%
se1.pop(10)

# %%
se1.pop()

# %%
se1

# %%
se2

# %%
se2.remove?

# %%
se2.remove(50)

# %% [markdown]
# ### set does indexing for faster search

# %%
se2.remove(10)

# %%
se2

# %%
se2.update({1,5,6,7})

# %%
se2

# %%
se2.update(())

# %%
se2.update([1,2,3])

# %%
se2

# %%
se2.update([1,2,8,[1,2,3]])

# %%
se2

# %%
se2.update("sdfg")

# %%
se2

# %%
se2.update?

# %%
se2.update([20,30,50,[]])

# %%
se2

# %%
len(se2)

# %%
se2.update([101,[],56])

# %%
len(se2)

# %%
se2

# %%
se2.discard?

# %%
se2.discard(101)

# %%
se2

# %%
se2.discard('y')

# %%
set1 = {1,2,5,6}

# %%
set2 = {3,4,5}

# %%
set1.union(set2)

# %%
set1

# %%
set2.union(set1)

# %%
set1.intersection(set2)

# %%
set2.intersection(set1)

# %%
set1.difference(set2)

# %%
set2.difference(set1)

# %%
set1.symmetric_difference(set2)

# %%
set1.issubset(set2)

# %%
set1.issuperset(set2)

# %%
set3 = {2,4,5,6}
set4 = {2,6}

# %%
set3.issubset(set4)

# %%
set3.issuperset(set4)

# %%
set1.isdisjoint?

# %%
set1.isdisjoint(set2)

# %%
set1

# %%
set2

# %%
set3

# %%
set4

# %%
set2.isdisjoint(set4)

# %%
set2.difference_update?

# %%
set1

# %%
set2

# %%
set1.difference_update(set2)

# %%
set1

# %%
set2

# %%
li = [1,5,5,6]
dep_li= []
for i in li:
    if dep_li.count(i) == 0:
        dep_li.append(i)

# %%
dep_li

# %%
list(set(li))

# %%
lis = [5,9,5,6,3,4,1,52,4,59,85,2,93,1,3,2,63,55,62,4,85,52]

# %%
set(lis)

# %%
print(1)

# %%
print("sdfgd")

# %%
print("adsds","asjfgash",123)

# %%
print("adsds","asjfgash",123,sep = ">>")

# %%
print("adsds","asjfgash",123,sep = ">>")
print("adsds","asjfgash",123,sep = ">>")

# %%
print("adsds","asjfgash",123,sep = ">>",end="***")
print("adsds","asjfgash",123,sep = ">>")

# %%
file = open("demo.txt","w")

# %%
print("Hello, My name is shubham")

# %%
print("Hello, My name is shubham",file=file)

# %%
file.close()

# %%
print?

# %%
file = open("demo.txt","a")

# %%
print("I am a Data Science Trainer",file=file,flush=True)

# %%
file.close()

# %%
file = open("demo.txt","r")

# %%
file.read()

# %%
file.seek(0)

# %%
print(file.read())

# %%
se1

# %%
kl = frozenset(set1)

# %%
kl

# %%
kl.

# %%
set1.
