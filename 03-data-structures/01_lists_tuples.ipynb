# %% [markdown]
# # Curated lesson: 01_lists_tuples
# Source: `B07_Python/Day7.ipynb`.
# This notebook was migrated into the structured Python Course and execution outputs were removed so students can run the examples themselves.

# %% [markdown]
# Understanding Lists
# Indexing and slicing in lists
# List methods: append(), extend(), insert(), remove(), pop(), clear(), index(), count(), sort(), reverse()
# Example of adding grocery items

# %% [markdown]
# # List

# %%
lis = []

# %%
type(lis)

# %%
len(lis)

# %%
lis1 = list()

# %%
type(lis1)

# %%
lis1

# %%
lis

# %%
lis.append(5) #single object,right side insert

# %%
lis

# %%
lis.append("sdgs")

# %%
lis

# %%
lis.append(56)

# %%
lis

# %%
lis[0]

# %%
lis[1]

# %%
lis[10]

# %%
lis[0] = 56

# %%
lis # inplace changes

# %%
str1 = "asdhd"

# %%
str1[0]

# %%
str1[0]="g"

# %%
lis

# %%
lis.clear() # empty list,all values are removed

# %%
lis

# %%
lis.append("Shubham")

# %%
lis

# %%
lis.extend("Shubham")# iterable,adds by breaking data into small,unit character

# %%
lis

# %%
lis.append(1564)

# %%
lis

# %%
lis.extend(1564)

# %%
num = 1234

# %%
num[0]

# %%
lis.extend('1564')

# %%
lis

# %%
lis.extend([12,45,78,98,"sfst"])

# %%
lis

# %%
lis.append([12,45,78,98,"sfst"])

# %%
lis

# %%
# Notebook help syntax is intentionally shown as a comment.
# In Jupyter, `lis.insert?` displays documentation for `list.insert`.
# Prefer `help(list.insert)` in portable Python code.

# %%
lis.insert(0,"sd")

# %%
lis

# %%
lis.insert(100,123)

# %%
lis

# %%
lis[0] = 256

# %%
lis

# %%
lis[2]= 56 #mutate index 2

# %%
lis

# %%
lis[2]

# %%
id(lis[2])

# %%
lis[2]=5

# %%
id(lis[2])

# %%
del lis[2]

# %%
lis

# %%
lis[2]

# %%
lis[-1]

# %%
lis[-2]

# %%
lis[0:5]

# %%
lis[:5]

# %%
lis[5:]

# %%
lis[:5] + lis[5:]

# %%
lis*2

# %%
lis[:] # copy

# %%
lis[:-1]

# %%
lis[-1:-5] #slicing dont produce error even if out of range

# %%
lis[-2:-5]

# %%
lis[-1:-5:-1]

# %%
lis[-1:-5:-2]

# %%
lis[::-1]

# %%
lis

# %%
lis.count("h")

# %%
lis.count("sfst")

# %%
id(lis)

# %%
lis.copy()

# %%
lis_copy = lis.copy()

# %%
id(lis_copy)

# %%
lis

# %%
lis.index("S")

# %%
lis.index("o")

# %%
lis.index("g")

# %%
lis.index(12)

# %%
lis

# %%
lis[5]

# %%
lis.insert(5,2)

# %%
lis[5]

# %%
lis

# %%
len(lis)

# %%
lis.insert(100,25)

# %%
lis

# %%
lis.insert(-100,25)

# %%
lis

# %%
lis[-1]

# %%
lis.pop()

# %%
lis[-1]

# %%
lis[5]

# %%
lis.pop(5)

# %%
lis.pop(100)

# %%
lis[5]

# %%
lis[10]

# %%
lis.pop(10)

# %%
lis[10]

# %%
lis.pop?

# %%
lis.remove?

# %%
lis

# %%
lis.remove(10)

# %%
lis.remove(5)

# %%
lis.remove(25)

# %%
lis

# %%
lis.remove('h')

# %%
lis

# %%
lis.append(2)

# %%
lis

# %%
lis.remove(2)

# %%
lis

# %%
lis.reverse()

# %%
lis

# %%
lis[::-1]

# %%
lis

# %%
lis.sort()

# %%
lis2 =[1,52,45,26,3]

# %%
lis2.sort()

# %%
lis2

# %%
lis2.sort(reverse=True)

# %%
lis2

# %%
lis3 = ["sd","cdf","ery","cfg","dc"]

# %%
lis3.sort()

# %%
lis3

# %%
lis3.sort(reverse=True)

# %%
lis3

# %%
sorted(lis3)

# %%
y = lis3.sort()

# %%
lis3

# %%
print(y)

# %%
y = sorted(lis3)

# %%
y

# %% [markdown]
# ## Example of adding Grosary item

# %%
cart =[]

# %%
cart.append("fish")

# %%
cart

# %%
cart.append("egg")

# %%
cart

# %%
cart.append("sugar")

# %%
cart

# %%
cart.remove("sugar")

# %%
cart

# %%
cart.clear()

# %%
cart

# %% [markdown]
# ## List comprehansion

# %% [markdown]
# List generation in single line compact code

# %%
lis.

# %%
list(range(10,20))

# %%
range?

# %%
x = iter(range(10,20))

# %%
x

# %%
next(x)

# %%
tuple(range(5))

# %%
list(range(1,5,2))

# %%
x = range(10)

# %%
x

# %%
x = iter(x)

# %%
next(x)

# %%
[num**3 for num in range(10)] # list comprehension

# %%
[i*j for i in range(1,11) for j in range(1,11)]

# %%
range("A","Z")

# %%
lis = [(1,2),45,"ssd"]

# %%
lis[0] = list(lis[0])

# %%
lis

# %%
tup = ([1,2],45,"ssd")

# %%
tup[0][0]= tuple(tup[0])

# %%
tup.

# %%
tup[0]

# %%
tup[0][0] = 25

# %%
tup

# %%
tup[0].pop()

# %%
id(tup)

# %%
tup[0][0] = 36

# %%
id(tup)

# %%
tup[0] =[]

# %%
task = []

# %%
task.append("Take Dog for a walk")

# %%
task

# %%
task.append("Do some Yoga Practice")

# %%
task

# %%
task.append("Take a shower")

# %%
task

# %%
task.append("Do a prayer")

# %%
task.append("Pack lunch box")

# %%
task.append("Not to forget your laptop")

# %%
task.append("Double check that you locked the door well")

# %%
task.append("You have to attend meeting at 2:30 pm with hr on salary increament")

# %%
task

# %%
for i,j in enumerate(task):
    print(i,"==>>",j)

# %%
task.pop(0)

# %%
task

# %%
for i,j in enumerate(task):
    print(i,"==>>",j)

# %%
task.pop(3)

# %%
task.remove("Not to forget your laptop")

# %%
task

# %%
task1 = []

# %%
task1.extend(task)

# %%
for i,j in enumerate(task1):
    print(i,"==>>",j)

# %%
task.clear()

# %%
task

# %%
task1.insert(0,"Go for a morning walk")

# %%
for i,j in enumerate(task1):
    print(i,"==>>",j)

# %%
task1[0] = "Instead go for 1 km speed run and one more thing you need to complete it in 6 mins."

# %%
for i,j in enumerate(task1):
    print(i,"==>>",j)

# %%
def task_viver(no_of_task=None):
    for i,j in enumerate(task1[:no_of_task]):
        print(i,"==>>",j)

# %%
task_viver()

# %%
task_viver(2)

# %%
len(task1)

# %%
task1.remove("Take a shower")

# %%
task_viver(len(task1))

# %%
task1.pop(2)

# %%
task_viver(len(task1))

# %%
task1.sort()

# %%
task_viver(len(task1))

# %%
task1.sort(reverse=True)

# %%
task_viver(len(task1))
