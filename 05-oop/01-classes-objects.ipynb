# %% [markdown]
# # Curated lesson: 01-classes-objects
# Source: `B07_Python/Day16-oop1.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %%
print(type(len))

# %%
print(type(print))

# %%
print(type(int))

# %%
print(type(float))

# %%
print(type(str))

# %%
class animal:
    pass

# %%
s = animal()

# %%
print(type(s))

# %%
s = int()

# %%
print(type(s))

# %%
s = 123

# %%
s = int(123)

# %%
type(s)

# %%
print(type(s))

# %%
a = animal()

# %%
a

# %%
class animal:
    """We are creating a class called animal"""
    jungle = "Amazon"
    def __init__(self,species,age,weight):
        print(id(self))
        self.species = species
        self.age = age
        self.weight = weight
        print(f"Animal Created: {self.species}, Age: {self.age}")
    def __repr__(self):
        return f"Animal: {self.species}, Age: {self.age}"
    def walk(self):
        print(f"{self.species} is walking")
    
    @staticmethod
    def hello():
        return "welcome to animal class"

# %%
animal()

# %%
a1 = animal("Dog", 5,20)

# %%
a1.hello()

# %%
id(a1)

# %%
 a2=animal("lion",3,150)

# %%
id(a2)

# %%
a1.species

# %%
a2.species

# %%
a1.__dict__

# %%
a1.species

# %%
a1.age

# %%
a1.weight

# %%
a1.weight = 20

# %%
a1.weight

# %%
a1.__dict__

# %%
a2.__dict__

# %%
animal.__dict__

# %%
a2.walk()

# %%
a1.walk()

# %%
animal.jungle

# %%
a1.jungle

# %%
a2.jungle

# %%
del a2.age

# %%
a2.__dict__

# %%
animal.jungle = "Sundarban"

# %%
animal.__dict__

# %%
a1.jungle

# %%
a1.jungle = "Pench"

# %%
a1.__dict__

# %%
a2.jungle

# %%
class complexx:
    """
    we want to built an implimentation of python complex class.
    """
    counter = 0
    iscomplex = True
    def __init__(self,real,imag): # constructur method-- initilizer #__dgfh__ dunder method
        self.real = float(real) # private
        self.imag = float(imag)
        complexx.counter += 1
    
    def __repr__(self):
        if '-' in str(self.imag):
            return  f"({self.real}{self.imag}i)"
        return f"({self.real}+{self.imag}i)"

    def __add__(self,other):
        real = self.real + other.real
        imag = self.imag + other.imag
        
        return complexx(real,imag)
    
    def __sub__(self,other):
        real = self.real - other.real
        imag = self.imag - other.imag
        return complexx(real,imag)
    def __mul__(self,other):
        real = self.real * other.real
        imag = self.imag * other.imag
        
        return complexx(real,imag)
    
    def __eq__(self,other):
        return (self.real == other.real) and (self.imag == other.imag)

    def __gt__(self,other):
        return (self.real +self.imag) > (other.real + other.imag)

    def __ge__(self,other):
        return ((self.real +self.imag) > (other.real + other.imag)) \
        or ((self.real == other.real) and (self.imag == other.imag))
    """# getter method
    @property
    def real(self,passwd):
        if passwd == '123':
            return self.real
        else:
            print("Bhag yahase")

    # setter method
    @real.setter
    def real(self):
        passwd = input("Enter Passwd:\n")
        if passwd == '123':
            new = input("Enter new value:\n")
            self.__real =float(new)
            print("Value updated sucessfully")
        else:
            print("Invalied Credential,Try Again....")

    @classmethod
    def get_counter(cls):
        return cls.counter"""

# %%
s = complexx(10,20) # self=s,real=10,imag =20

# %%
s.iscomplex

# %%
s.counter

# %%
s.imag

# %%
s.real

# %%
s

# %%
s1 = complexx(12,-58)

# %%
s1

# %%
s1.imag

# %%
s1.counter

# %%
s1+s

# %%
s == s1

# %%
s != s1

# %%
s > s1

# %%
s < s1

# %%
s >= s1

# %%
s.real('123')

# %%
'123'._iscomplex

# %%
s._iscomplex

# %%
s._iscomplex

# %%
s.real(123)

# %%
id(s)

# %%
s.__dict__

# %%
c = complexx(20,56)

# %%
id(c)

# %%
complexx.__counter

# %%
s.counter

# %%
c.counter

# %%
complexx.get_counter()

# %%
s.__dict__

# %%
complexx.__dict__

# %%
print(complexx.__doc__)

# %%
s.real

# %%
s.__real

# %%
s._complexx__real

# %%
s.get_real()

# %%
complexx.real

# %%
complexx.s.real

# %%
s.real=20

# %%
s.real

# %%
com = 10+20j

# %%
com.real # getter

# %%
com

# %%
c.real

# %%
c.__dict__

# %%
s.real=25

# %%
s.real

# %%
s

# %%
c

# %%
c.imag

# %%
d = complexx(5,-5)

# %%
d

# %%
d+s

# %%
com+(20+5j)

# %%
com

# %%
d-s

# %%
d

# %%
s

# %%
"sytrt"+3

# %%
d*s

# %%
d==s

# %%
d!=s

# %%
d>s

# %%
d<s

# %%
d.get_real('123')

# %%
d.set_real()

# %%
d.get_real('123')

# %%
class student:
    pass

# %%
stu1 = student()

# %%
type(stu1)

# %%
stu1.name = "shubham"

# %%
stu1.name

# %%
stu1.age = 30

# %%
stu1.age

# %%
stu2 = student()

# %%
type(stu2)

# %%
stu2.name

# %%
stu2.name = "palash"

# %%
stu2.name

# %%
stu1.name

# %%
class student1:
    classNo = 1 # class attribute

    def __init__(self,name,age):
        print(id(self))
        self.name = name # instance attribute
        self.age = age

# %%
s1 = student1()

# %%
s1 = student1("shubham",30)

# %%
s1.name

# %%
s1.age

# %%
s2 = student1("nikita",28) #(s2,"nikita",28)

# %%
s2.name

# %%
s2.age

# %%
id(s1)

# %%
id(s2)

# %%
s1.__dict__

# %%
s2.__dict__

# %%
s1.salary

# %%
s1.salary = 30000

# %%
s1.salary

# %%
s1.__dict__

# %%
s1.classNo

# %%
s2.classNo

# %%
s2.__dict__

# %%
s1.classNo = 2

# %%
s1.classNo

# %%
s2.classNo

# %%
s1.__dict__

# %%
s2.__dict__

# %%
student1.classNo = 2

# %%
s2.__dict__

# %%
s2.classNo

# %%
student1.fees = 60000

# %%
s1.fees

# %%
s2.fees

# %%
student1.fees

# %%
s1.fees = 58000

# %%
s1.fees

# %%
s1.update({"x":123})

# %%
student1.__dict__

# %%
s1.name

# %%
s1.name = "mukesh"

# %%
s1.name

# %%
student1.name = 123
