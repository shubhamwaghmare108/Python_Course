# %% [markdown]
# # Curated lesson: 01-exceptions
# Source: `B07_Python/Day20-Exception.ipynb`.
# Migrated into the structured Python Course. Outputs were removed and credential-like values were replaced with placeholders.

# %%
x = 10
y = 0

# %%
x/y

# %%
10/1

# %%
b = 0
while True:
    
    try:
        10/b
        break
    except ZeroDivisionError:
        print("Division by zero is not possible")
        break
    except NameError:
        globals()['b'] = 10
    except Exception as e:
        print(e)
print(10+20)

# %%
m = 0
while True:
    
    try:
        10/m
        break
    except Exception as e:
        print(e)
        break
    except ZeroDivisionError:
        print("Division by zero is not possible")
        break
    except NameError:
        globals()['m'] = 10
    
print(10+20)

# %%
class InvaliedAgeError(Exception):
    pass

# %%
while True:
        age = int(input("Enter your age:"))
        if age <0 or age >120:
            raise InvaliedAgeError("Age should be between 0 to 120")

# %%
replay = "no"
while replay == "no":
    replay = input("Do you love ml ?")

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator  # This will raise a ZeroDivisionError
    print(result)
except Exception as e:
    print("Oops! You can't divide by zero.")

print("Program continues after the try-except block.")

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print(f"The result is: {result}")
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("You cannot divide by zero!")

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print(f"The result is: {result}")
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("You can't divide by zero!")

# %%
try:\n    with open("my_file.txt", "r", encoding="utf-8") as file:\n        contents = file.read()\nexcept FileNotFoundError:\n    print("The file was not found.")\nelse:\n    print("File opened successfully!")\n    print(contents)

# %%
try:
    print(asfdfhh)
    file = open("another_file.txt", "r")
    content = file.read()
    print(content)
except (FileNotFoundError,NameError):
    print("Unexpected Thing Happen,Please try after sometime.")
finally:
    # This will always execute, regardless of whether an error occurred
    print("Attempting to close the file if opened...")
    if 'file' in locals() and not file.closed:
        file.close()
        print("File closed.")

# %%
def calculate_age(year_of_birth):
    if year_of_birth > 2026:
        raise FutureBirthError("Future Birth not possible")
    else:
        return 2026 - year_of_birth

try:
    age = calculate_age(2030)
except FutureBirthError as e:
    print(f"Error: {e}")

# %%
class FutureBirthError(Exception):
    pass

# %%
class InvaliedDataError(Exception):
    pass

# %%
lis = [123,456,789,"str"]
error = []
try:
    for i in lis:
        i+123
except TypeError:
    lis.remove(i)
    error.append(i)
    raise InvaliedDataError("Data Should Be Numeric")

# %%
lis

# %%
error
