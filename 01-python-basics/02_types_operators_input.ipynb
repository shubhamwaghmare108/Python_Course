# %% [markdown]
# # Curated lesson: 02_types_operators_input
# Source: `B07_Python/Day4.ipynb`.
# This notebook was migrated into the structured Python Course and execution outputs were removed so students can run the examples themselves.

# %% [markdown]
# # Indexing And Slicing in String

# %%
name = "Shubham Waghmare"
for i,j in enumerate(name):
    print(i,j)

# %%
reversed_name = name[::-1]
i = -1
for j in reversed_name:
    print(i,j)
    i-=1

# %%
name

# %%
name[2]

# %%
name[-14]

# %%
name[7]

# %%
name[-10]

# %%
name[-1]

# %%
name[-9]

# %%
name[-17]

# %%
name[17]

# %% [markdown]
# ## Slicing

# %%
name

# %%
name[4:10] # (start:stop:step=1) End not included

# %%
name[-5:-10]

# %%
name[-5:-10:-1]

# %%
name[-5:-10:-2]

# %%
name

# %%
name[-5:3]

# %%
name[-5:3:-1]

# %%
name[-12:-6]

# %%
name[-12:10]

# %%
name

# %%
name[4:10]

# %%
name

# %%
name[::-1]

# %%
name[:0:-1]

# %%
name[::2]

# %%
name[:5]

# %%
name[4:]

# %%
name[4::-1]

# %%
name

# %%
name[5::-1]

# %%
name[0::-1]

# %%
name[0:0:-1]

# %%
name[4:10:-1]

# %%
name[4:10:2]

# %%
name[20::1]

# %%
name[20]

# %%
name

# %%
name[20::-1]

# %%
name[12:100]

# %%
frozenset([1,2,3,4])[0]

# %% [markdown]
# # List Indexing

# %%
list1 = [1,2,5,3,6,8]

# %%
list1[-2]

# %%
list1[5]

# %%
list1[1:1]

# %%
list1[100]

# %% [markdown]
# # Tuple

# %%
tup = (1,5,65,89,8,5)

# %%
tup[-1]

# %%
tup[2:4]

# %%
tup

# %%
tup[6]

# %%
tup[:100]

# %% [markdown]
# # Item Assignment

# %%
tup

# %%
tup[-3] = 98

# %%
name

# %%
name[5] = "l"

# %%
list1

# %%
list1[-3] = 56

# %%
list1

# %%
list1[:2] = [2]

# %%
list1

# %%
list1[:2] = [1,2,3,4,5,6]

# %%
list1

# %%
del list1[0]

# %%
list1

# %%
tup = list(tup)

# %%
tup.append([12,3,6])

# %%
tup = tuple(tup)

# %%
tup

# %%
tup[-1][-1] = 7

# %%
tup

# %% [markdown]
# # String Methods

# %%
name = "shubham waghmare"

# %%
name

# %%
type(name)

# %%
name.upper()

# %%
id(name)

# %%
name

# %%
name.lower()

# %%
name.title()

# %%
name.capitalize()

# %%
name.swapcase()

# %%
'Shubham waghmare'.swapcase()

# %%
name.endswith?

# %%
name.endswith("s")

# %%
name

# %%
name.endswith?

# %%
name.endswith("m",0,7)

# %%
name.endswith(("e","h"))

# %%
"haam".endswith(("e","h"))

# %%
"haah".endswith(("e","h"))

# %%
name.endswith("E")

# %%
name

# %%
name.startswith?

# %%
name

# %%
name.startswith("m")

# %%
name.startswith("s")

# %%
name.startswith(("u","m"),3,5)

# %%
name.find?

# %%
name

# %%
name.find("m") # first serach result index num is return,left to right

# %%
name.find("1") # if  not found return -1

# %%
name.find("m",7,9)

# %%
name.index("1")

# %%
name

# %%
name.index("M")

# %%
name.center?

# %%
name.center(50)

# %%
name.center(25,"?")

# %%
#name.[Tab] to see operation available

# %%
name

# %%
name.find("h",3,5)

# %%
name.index?

# %%
name.find("m W")

# %%
name.find("m w")

# %%
name.find("am"[0:15])

# %%
name

# %%
name.ljust?

# %%
name.ljust(50,"*")

# %%
name.ljust(50,"*/")

# %%
name.ljust(50,"5")

# %%
name.rjust(50,"*")

# %%
text = "asvascndsvknsdasc"
text.count("a")

# %%
text = "asvascndsvknsdasc"
lis = []
last = 0

while True:
    result = text.find("s", last)
    if result == -1:
        break
    lis.append(result)
    last = result + 1

print(lis)

# %%
lis

# %%
name

# %%
name[5:7]

# %%
name.upper?

# %%
name.upper()

# %%
name

# %%
name.lower?

# %%
name.lower()

# %%
name = "Shubham waghmare"

# %%
name.title?

# %%
name.title()

# %%
name.capitalize?

# %%
name.capitalize()

# %%
"shubham9waghm9are".title()

# %%
name

# %%
name.swapcase()

# %%
name

# %%
name = name.swapcase()

# %%
name

# %%
name.count("m")

# %%
name

# %%
name.count("a")

# %%
name.count(" ")

# %%
name.count("1 ")

# %%
a="sjsjdk"

# %%
b="asdjsa"

# %%
c= a+b

# %%
a

# %%
b

# %%
c

# %%
sample = ",".join([a,b,c])

# %%
sample

# %%
sample.split?

# %%
sample

# %%
sample.split("s")

# %%
sample.split(",",1)

# %%
"sjsjdk" + "asdjsa" # concatination

# %%
"shubham"+" "+"waghmare"

# %%
"I Love Python\n"*3

# %%
a

# %%
a*3

# %%
a

# %%
"sd"*3 # repitation

# %%
" ".join(["fgg","dsd","fdf"])

# %%
"fgg"+" "+"dsd"+" "+"fdf"

# %%
name

# %%
(name.split(" "))

# %%
(name.partition(" "))

# %%
"".join(name.partition(" "))

# %%
name.lower().split("h")

# %%
name.lower().partition("h")

# %%
name.partition?

# %%
name = name.lower()

# %%
"".join(name.partition("h"))

# %%
"h".join(name.split("h"))

# %%
name

# %%
name.isalnum()

# %%
'Shubhamwaghmare'.isalnum()

# %%
name.isalpha()

# %%
'Shubhamwaghmare108'.isalpha()

# %%
name.isdecimal()

# %%
"123".isdecimal()

# %%
"123.10".isdecimal()

# %%
name

# %%
name.isupper()

# %%
name.islower()

# %%
name

# %%
name.istitle()

# %%
name.isspace()

# %%
"      ".isspace()

# %%
name.ljust(30,"**")

# %%
name.rjust(30,"*")

# %%
name.lstrip()

# %%
"   adsasdj   ".lstrip()

# %%
"  sdh    ".rstrip()

# %%
"  sdh    ".strip()

# %%
"shubham   waghmare".strip()

# %%
"shubham   waghmare".replace("s","5321")

# %%
"shubham   waghmare".replace("   "," ")

# %%
"123sa123dg__ajs".isidentifier()

# %%
"".isidentifier()

# %%
"sdas ajd".

# %%
s = """asfdas
hasgcas
adgas
ashsdj"""

# %%
s

# %%
print('asfdas\nhasgcas\nadgas\nashsdj')

# %%
print(s)

# %% [markdown]
# # Escape Character

# %%
\\,\',\",\n,\t

# %%
print("dsaad\tdsa")

# %%
print("dsaad\ndsa")

# %%
'I don't care'

# %%
'I don\'t care'

# %%
"I don't care"

# %%
print("I like \\Ml")

# %%
"I don"t care"

# %%
"I don\"t care"

# %%
"I don't care,"Get Out.""

# %%
"I don't care,\"Get Out.\""

# %%
'''I don't care,\"Get Out.\"'''

# %%
'''I don't care,"Get Out."'''

# %% [markdown]
# # Type Casting

# %%
s = "123"

# %%
type(s)

# %%
s+123

# %%
int(s)+123

# %%
num = 123

# %%
type(num)

# %%
num+"sgjs"

# %%
str(num)+"sgjs"

# %%
float_ = 123.25

# %%
str(float_)+"sgs"

# %%
int("123,")

# %%
int("123asd")

# %%
tupl = (1,"sds",56)

# %%
type(tupl)

# %%
tupl = list(tupl)

# %%
tupl.append(23)

# %%
tupl

# %%
tupl = tuple(tupl)

# %%
tupl

# %%
list_ = [123,7889,"gds",46,(1,2,3)]

# %%
type(list_)

# %%
tuple(list_)

# %%
list_

# %%
list(str(list(str(list_))))

# %%
list_ = [1,1,5,2,2,3,4,5,1]

# %%
list(set(list_))

# %%
float(123)

# %%
int(123.56)

# %%
list_

# %%
dict(list_)

# %%
12 + 12.35

# %%
5 / 5

# %% [markdown]
# # Some basic Functions

# %%
type(1)

# %%
print("hello","123",123)

# %%
print?

# %%
print(123);print(456)

# %%
print(123,end = "++++")
print(456)

# %%
print(123,456,789)

# %%
print(123,456,789,sep = "**")

# %%
file = open("test.txt","w")

# %%
print(123,456,789,file = file)

# %%
file.close()

# %%
file = open('test.txt','r')

# %%
file.read()

# %%
file.close()

# %%
print(123+456)

# %%
print('123+456')
print()
print(123+456)

# %%
input()

# %%
input("enter your age\n")

# %%
age = int(input("enter your age\n"))

# %%
age

# %%
age + 5

# %%
id(5)

# %%
id(6)

# %%
id(5)

# %%
id(259)

# %%
id(259)

# %%
x = 259

# %%
y = 259

# %%
x == y

# %%
x is y

# %%
25 + 56

# %%
_-58

# %%
_*2

# %%
_/2

# %%
_//1

# %%
_**2

# %%
_%13

# %%
533%13

# %%
print("hello ,shubham")

# %%
name = input("Enter your name:\n")
massage = input("Enter your query:\n")
greet = f"Hello,{name},i got your massage like this \"{massage}\",please confirm i got it write." # f string formatting
print(greet)

# %%
id(greet)

# %%
x = "hi,how are you ?\n{x},{y}".format(y = 0,x = "good")

# %%
print(x)

# %%
"hi,how are you ?\n %d %d"%(10,20)

# %%
id(123)

# %%
x = 123

# %%
id(x)

# %%
x = 257

# %%
y = 257

# %%
x == y

# %%
x is y

# %%
id(x)

# %%
id(y)

# %%
x = 10
y = 10

# %%
x == y

# %%
x is y

# %%
"hello,shubham"

# %%
name = 'sahil'
greeting = f"hello,{name}"

# %%
greeting

# %%
name = 'raj'

# %%
name

# %%
greeting

# %%
"hello,{name}".format(name = name)

# %%
"hello,%d"%('123')

# %%
"hello,%.1f"%(123.123)
