# %% [markdown]
# # Curated lesson: 01_variables_strings
# Source: `B07_Python/Day3.ipynb`.
# This notebook was migrated into the structured Python Course and execution outputs were removed so students can run the examples themselves.

# %% [markdown]
# # Variables in python

# %%
name = "krunal" # Binding

# %%
age = 20

# %%
name

# %%
age

# %%
name = "Harsh" #Rebinding

# %%
name

# %%
29

# %%
id(29)

# %%
age = 29

# %%
print(age)

# %%
id(age)

# %%
789456623233

# %%
id(789456623233)

# %%
num = 789456623233

# %%
id(num)

# %%
id(257)

# %%
num1 = 257

# %%
id(num1)

# %%
name = '''shubham''' # '',"",--single line string,""" """",''' '''-- multiline string

# %%
name[2]

# %%
name[-2]

# %%
name[2:-1:-1] # start:end:step --direction stride

# %%
name

# %%
name[::1]

# %%
name[-1:-3:-2]

# %%
x = '''svscsc
scvhmchvc
scvdmcbdsh'''

# %%
type(name)

# %%
del age

# %%
print(age)

# %%
id(29)

# %%
num =29

# %%
id(num)

# %%
age = 32

# %%
age

# %%
type(age) # data type

# %%
type(name)

# %%
first_name

# %%
first_name = name

# %%
first_name

# %%
name

# %%
id(first_name),id(name)

# %%
First_name = "shubham"

# %%
id(First_name)

# %%
lis1 =[1,2,3]

# %%
lis2 =lis1

# %%
id(lis2),id(lis1)

# %%
lis2.append(4)

# %%
lis2

# %%
lis1

# %%
lis3 = [1,2,3,4]

# %%
id(lis1),id(lis3)

# %%
lis3.append(5)

# %%
lis1

# %%
lis2

# %%
lis3

# %% [markdown]
# ## Naming rule

# %% [markdown]
# [a-z,A-Z,0-9,_ ]  # allowed charcater set for name

# %%
"a" == "A" # Python is case sensative

# %% [markdown]
# 1.Do not use number at start

# %%
9fdshfh = 123

# %%
fgggh8956233 = 123

# %%
fgggh8956233

# %% [markdown]
# 2.Space not allowed.

# %%
first name = "Shubham"

# %%
first_name = "Shubham" #snake case

# %%
first_name

# %%
f9dshfh = 123

# %%
ab = 123

# %%
ab

# %%
_ = 123

# %%
_

# %% [markdown]
# 3.Keywards not allowed as variable name.

# %%
import keyword

# %%
keyword.kwlist

# %%
len(keyword.kwlist)

# %%
if = 123

# %%
from = 123

# %%
If = 456

# %%
If

# %%
From = 789

# %%
a = 123

# %%
A = 456

# %%
a

# %%
A

# %%
a = 123

# %%
a = 456

# %%
a

# %%
a = 789

# %%
a

# %% [markdown]
# # Build in data types

# %%
number---> int,float,complex

# %%
int --> 10,52,46,56 ,-59

# %%
a = 123

# %%
type(a)

# %%
float --> 12.0,13.25,16.45,-56.26

# %%
a = 12.0

# %%
type(a)

# %%
complex ---> real+imag
imag -->j,J

# %%
a = 12+13j

# %%
type(a)

# %%
a.real

# %%
a.imag

# %%
b = -12j

# %%
type(b)

# %%
b.real

# %%
b.imag

# %%
type(0b101010)# [1,0]

# %%
type(0x2a)#[0-9,a-f]

# %%
type(0o52)#[0-7]

# %%
x = bin(42)

# %%
x

# %%
type(x)

# %%
y = oct(42)

# %%
type(y)

# %%
y

# %%
z = hex(42)

# %%
type(z)

# %%
z

# %%
type('0b1010')

# %%
text--->str

# %%
name = 'Shubham'

# %%
type(name)

# %%
name = "dsdg"

# %%
type(name)

# %%
sentence = 'I don't like it'

# %%
sentence = "I don't like it"

# %%
a = "1213"

# %%
type(a)

# %%
a + 10

# %%
a = 1213

# %%
type(a)

# %%
a+10

# %%
'sfg"

# %%
'ghjj'dfgghg'

# %%
"ghjj'dfgghg"

# %%
'hvfsdv\'cbsac'

# %%
4+3

# %%
#4+3

# %%
"""sjfcsdvkdv
asgvsacjsdcv = 10"""

# %%
"hfhfhj13232sgdh24#%$^%^&" # single line string '',""

# %%
"ndgfgh
dfgkh
sdfgh"

# %%
var = """ndgfgh
dfgkh
sdfgh"""

# %%
var

# %%
print(var)

# %%
'''ndgfgh
dfgkh
sdfgh'''

# %%
print('''ndg\tf\ngh
dfgkh
sdfgh''')

# %%
"scvsvb""sgcdsvcs"

# %%
"cscd" + " "+"gscvsdcv" # concatination

# %%
print("I love python\n" *10) # string repitation

# %%
boolean -->True,False

# %%
IsNight = False # Pascal case

# %%
print(IsNight)

# %%
type(IsNight)

# %%
False

# %%
isClassToday = True #Camel case

# %%
type(isClassToday)

# %%
6 == 6.4

# %%
True--->1,False--->0

# %%
True + True

# %%
False + True

# %%
1 + True

# %%
None

# %%
gft = None
type(gft)

# %%
type({})

# %%
hash(123)

# %%
hash(123.15)

# %%
hash("sdsvkdsb")

# %%
hash([])

# %%
hash(())

# %%
hash(([],123))

# %%
type({})

# %%
hash({})

# %%
a = set()

# %%
a.add(123)

# %%
a

# %%
hash(a)

# %%
Collection Type---> list,tuple,set,frozenset

# %%
a = [123,"sgfg",1223]

# %%
a

# %%
type(a)

# %%
len(a)

# %%
a[2]=1564

# %%
a

# %%
a.pop()

# %%
a

# %%
a.append(123456)

# %%
a

# %%
b = 123,456,789,"shubham"

# %%
type(b)

# %%
print(b)

# %%
(123)+(456)

# %%
s = (123)

# %%
type(s)

# %%
s = (123,)

# %%
type(s)

# %%
a = 123,456,"sfgh"

# %%
type(a)

# %%
a = (123,[123,456],"sdgh")

# %%
type(a)

# %%
a[1].append(56)

# %%
a

# %%
for i in a:
    print(i,id(i))

# %%
a[1].append(459)

# %%
for i in a:
    print(i,id(i))

# %%
id(a)

# %%
a[1].append(9)

# %%
id(a)

# %%
type(a)

# %%
b = (1)*(5)

# %%
type(b)

# %%
b = (1.0)

# %%
type(b)

# %%
b = ()

# %%
type(b)

# %%
c= ""

# %%
type(c)

# %%
set -->{1,2,3} #no duplicate allowed

# %%
se = {1,2,3,3}

# %%
se

# %%
type(se)

# %%
se={1,2,3,3,3,3,3,3,3,3,3,3,3,3,3,3}

# %%
se

# %%
se.add(156)

# %%
se

# %%
se.add("sshg")

# %%
se # hashable --change not allowed

# %%
se.add([123])

# %%
type([])

# %%
type(())

# %%
type({})

# %%
type(set())

# %%
(1,1)

# %%
[1,1]

# %%
{1,1,1,2}

# %%
mapping type ---> dict{"Key":"Value"}

# %%
dict1 = {1:456,2:789}

# %%
dict1[2] # mutable

# %%
dict1.update({3:123})

# %%
dict1

# %%
# dict not allowed duplicate keys

# %%
hash("s")

# %%
dict1.update({"S":89})

# %%
dict1

# %%
dict1["S"]

# %%
# dict keys are hashable type and non duplicate,dict values are non hashable type and duplicate allowed

# %%
num,tuple,

# %%
dict1.update({[1,2]:123})

# %%
dict1.update({(1,2):123})

# %%
dict1.update({(1,2,[123]):123})

# %%
dict1

# %%
dict1.update({1:789})

# %%
dict1

# %%
None

# %%
a=None

# %%
a

# %%
print(a)

# %%
type(a)

# %%
var = {}

# %%
type(var)

# %%
var1 = set()

# %%
type(var1)

# %%
dict1

# %%
dict1["S"]

# %%
for i in dict1.keys():
    print(i,type(i))

# %%
dict1.update({"1":123})

# %%
dict1

# %%
for i in dict1.keys():
    print(i,type(i))

# %%
1+1

# %%
int("1")+1

# %%
a=[123,466,789]

# %%
a[5]

# %%
lis1 =[]

# %%
type(lis1)

# %%
dtr = {}

# %%
type(dtr)

# %%
stet = set()

# %%
type(stet)

# %%
stet.add(5)

# %%
stet

# %%
ty = tuple()

# %%
type(ty)

# %%
lis2 = list()

# %%
type(lis2)

# %%
num = "123a"

# %%
num+10

# %%
int(num)+10

# %%
lis1.append(5)

# %%
lis1

# %%
type(tuple(lis1))

# %%
type(None)

# %%
def addition(x,y):
    return

# %%
addition(12,13)

# %%
x = addition(12,13)

# %%
x

# %%
print(x)

# %%
set1 = {1,5,3,2,5}

# %%
set1

# %%
set1.add(156)

# %%
set1

# %%
forset = frozenset(set1)

# %%
type(forset)

# %%
forset.add(456)

# %%
frozenset([1,2,3])

# %%
frozenset({1, 2, 3, 5, 156})

# %%
frozenset((1, 2, 3))

# %%
set()

# %%
dict()

# %%
list()

# %%
tuple()

# %%
frozenset()
