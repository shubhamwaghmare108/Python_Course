# %% [markdown]
# # Curated Seaborn lesson
# Source: `B07_Python/Seaborn.ipynb`.
# Execution outputs were removed for a clean teaching notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df

# %%
sns.load_dataset?

# %%
df2 = sns.load_dataset("car_crashes")

# %%
df2

# %%
df

# %%
sns.barplot?

# %%
sns.barplot(df['sex'])

# %%
df['sex'].value_counts()

# %%
# `distplot` was removed from modern Seaborn. Use `histplot` or `displot` instead.

# %%
sns.histplot(df['age'], bins=5, kde=True)

# %%
sns.histplot(df['age'], bins=10, kde=True)

# %%
df['age'].skew()

# %%
sns.histplot(df['age'],bins=10,kde=True)

# %%
sns.histplot(df['age'],bins=[0,10,16,40,50,60,70,85],kde=True)

# %%
sns.displot?

# %%
sns.displot(df['age'],bins=[0,10,16,40,50,60,70,85],kde=True)

# %%
sns.displot(df['age'],kind="kde")

# %%
sns.displot(df['age'],kind="hist")

# %%
sns.displot(df['age'],kind="ecdf")

# %%
df["age"].median()

# %%
sns.scatterplot(df['age'])

# %%
df.columns

# %%
sns.scatterplot(data=df,x='sex',y='age')

# %%
sns.scatterplot(x=df['sex'],y=df['age'])

# %%
sns.scatterplot?

# %%
sns.scatterplot(df['age'])

# %%
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['sex'])

# %%
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['pclass'])

# %%
sns.scatterplot(x=df['survived'],y=df['age'])

# %%
df.query('pclass==2 and age>50').shape

# %%
sns.countplot(df["sex"])

# %%
df.dtypes

# %%
sns.countplot(df["pclass"].astype(str))

# %%
sns.countplot(df["embarked"])

# %%
sns.boxplot(df['age'])

# %%
df.query('age>65')

# %%
sns.violinplot(df['age'])

# %%
sns.scatterplot(x='age', y='fare', hue='sex', data=df)
plt.show()

# %%
sns.lineplot(x='age', y='fare', data=df)
plt.show()

# %%
sns.barplot(x='sex', y='fare', data=df)
plt.show()

# %%
corr = df[['age','fare','pclass','survived']].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(df[['age','fare','pclass','survived']])
plt.show()

# %%
sns.set_style("whitegrid")
sns.set_palette("Set2")

# %%
sns.barplot(x='sex', y='fare', data=df)
plt.show()
