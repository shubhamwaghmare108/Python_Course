# %% [markdown]
# # NumPy Array Creation
#
# Learn the main ways to create NumPy arrays and inspect their shape and dtype.

# %% [markdown]
# ## 1. From Python sequences
#
# ```python
# import numpy as np
#
# arr = np.array([10, 20, 30, 40])
# print(arr)
# print(arr.shape, arr.dtype)
# ```

# %% [markdown]
# ## 2. Ranges
#
# Practice `np.arange()`, `np.linspace()`, and understand when each is appropriate.

# %% [markdown]
# ## 3. Pre-filled arrays
#
# Practice `np.zeros()`, `np.ones()`, `np.full()`, and `np.empty()`.

# %% [markdown]
# ## 4. Identity matrices
#
# Use `np.eye()` to create square identity matrices.

# %% [markdown]
# ## 5. Random arrays
#
# Use `np.random.default_rng()` and a fixed seed when reproducible classroom results are required.

# %% [markdown]
# ## 6. Shape and dtype
#
# Inspect `.shape`, `.ndim`, `.size`, and `.dtype`. Convert dtype explicitly when needed.

# %% [markdown]
# ## Practice
#
# Create a 3×4 sales array, inspect its attributes, calculate its total, and create a reproducible random 3×4 comparison array.
