# %% [markdown]
# # Curated lesson: 02_loops
# Source: `B07_Python/Day6_A.ipynb`.
# This notebook was migrated into the structured Python Course and execution outputs were removed so students can run the examples themselves.

# %% [markdown]
# # Control Flow

# %% [markdown]
# ## If-elif-else

# %%
name = input("Enter Your Name:\n") # stroge in str form
print(type(name))
print(f"Hello,{name}")
print("Hello,",name)

# %%
name = int(input("Enter your age: ")) # stroge in str form
print(type(name))
print("Hello,",name)

# %%
float(2)/float(2)

# %%
int(3.56)

# %%
import math

# %%
math.ceil(3.12)

# %%
x= math.floor(3.12)

# %%
type(x)

# %%
is_trump_dead = input("Trump is dead? Give your answer 1 if yes : ")
if is_trump_dead == "1":
    print("Lauch missiles on iran,venenzula,n korea")
else:
    print("Trump will do it himself")

# %%
age = int(input("enter your age:"))
if age >= 18:
    print("you are eligible for voter registration")
else:
    print("not eligible")

# %%
age = int(input("enter your age:"))
if age >= 18:
    print("you are eligible for voter registration")
print(213)

# %%
age = int(input("enter your age:"))
if age>=18:
    print("you are eligible for voter registration")
else:
    print("not eligible")
print("Done")

# %%
age = int(input("enter your age:"))
if age==18:
    print("you are eligible for voter registration")
else:
    print("not eligible")
print("Done")

# %%
current_light = input("Enter trafic light color\n").lower().strip()

if current_light == "red":
    print("Traffic Light is RED: STOP! Do not proceed.")

elif current_light == "yellow":
    print("Traffic Light is YELLOW: Prepare to stop.\
    Clear the intersection if it is safe to do so.")

elif current_light == "green":
    print("Traffic Light is GREEN: PROCEED with caution.")

else:
    print("Invalid traffic light state. Something is wrong!")

# %%
name = input("Enter your name : ")
if "y" in name:
    print("Yes")
else:
    print("No")

# %%
name = "hubham" # nested structure
if "y" in name:
    print("y")
    if "s" in name:
        print("s")
    elif "b" in name:
        print("b")
else:
    print("there is no 'y' in name")
print("out")

# %%
if False:
    print("ok")

# %%
age = 60
has_membership= True

if age>=60 and has_membership==True:
    print("Eligible for discount")

else:
    print("Not eligible")

# %%
age = 30
has_membership= True

if age>=60 or has_membership==True:
    print("Eligible for discount")

else:
    print("Not eligible")

# %%
a = 333
b = 200
if b > a:
    print("b is greater than a")
elif b==a:
    print("b is equal to a")
else:
    print("b is less than a")

# %%
a = 34
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
print("out")

# %%
a = 200
b = 333
if b > a:
  print("a is greater than b")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")

# %%
a = 300
b = 33
c = 500
if a > b and c > a:
    print("c is greater than a and b")
    print("Both conditions are True")

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")

# %%
a = 33
b = 200
if not a > b:
  print("a is NOT greater than b")

# %%
x = 41

if x > 10:
    print("Above ten,")
    if x > 20:
        print("and also above 20!")
    else:
        print("but not above 20.")

# %%
x = 15

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")

# %%
x = 20

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")

# %%
x = 10

if x > 10:
    print("Above ten,")
    if x > 20:
      print("and also above 20!")
    else:
      print("but not above 20.")

else:
    print("less than or equal to 10")
